# %%
import pandas as pd
from streamlit import columns

# %% [markdown]
# ### Police Force Area Data Tables March 2024

# %%
df = pd.read_excel('../data/raw/pfatablesyemar24final.xlsx', sheet_name='Table P1', skiprows=6)

# %%
df.head()
# Out:
#    Area Code                   Area Name  \
# 0  K04000001  ENGLAND AND WALES [note 3]
# 1  E92000001                    ENGLAND
# 2  E12000001                  North East
# 3  E23000013                   Cleveland
# 4  E23000008                      Durham
#
#    Total recorded crime\n (excluding fraud) \n[note 2]  \
# 0                                            5402047
# 1                                            5059395
# 2                                             285315
# 3                                              76680
# 4                                              64285
#
#    Violence against the person  Homicide  Violence with injury  \
# 0                      2014390       583                556730
# 1                      1889562       556                524340
# 2                       107079        31                 30311
# 3                        28584        13                  7181
# 4                        25055         5                  5556
#
# ...

# %%
df.to_csv('../data/cleaned/police_force_area_mar_2024.csv')

# %% [markdown]
# ### Police Force Area Data Tables March 2023

# %%
df = pd.read_excel('../data/raw/pfatableyemar231.xlsx', sheet_name='Table P1', skiprows=6)

# %%
df.head()
# Out:
#    Area Code                     Area Name  \
# 0  K04000001  ENGLAND AND WALES [note 3]\n
# 1  E92000001                     ENGLAND\n
# 2  E12000001                    North East
# 3  E23000013                     Cleveland
# 4  E23000008                        Durham
#
#     Total recorded crime\n (excluding fraud) [note 2]  \
# 0                                            5584888
# 1                                            5244058
# 2                                             291131
# 3                                              84210
# 4                                              64094
#
#    Violence against the person  Homicide  Violence with injury  \
# 0                      2113383       602                573791
# 1                      1985379       569                541374
# 2                       109982        42                 30105
# 3                        31386        11                  7498
# ...

# %%
df.to_csv('../data/cleaned/police_force_area_mar_2023.csv')

# %% [markdown]
# ### Police Force Area Data Tables March 2022

# %%
df = pd.read_excel('../data/raw/pfafinalmar22.xlsx', sheet_name='Table P1', skiprows=6)

# %%
df.head()
# Out:
#    Area Code                   Area Name  \
# 0  K04000001  ENGLAND AND WALES [note 3]
# 1  E92000001                    ENGLAND
# 2  E12000001                  North East
# 3  E23000013                   Cleveland
# 4  E23000008                      Durham
#
#     Total recorded crime\n (excluding fraud) [note 2]  \
# 0                                            5335806
# 1                                            5017260
# 2                                             267956
# 3                                              73490
# 4                                              59145
#
#    Violence against the person  Homicide  Violence with injury  \
# 0                      2103151       710                566603
# 1                      1976656       676                534562
# 2                       105668        26                 28384
# 3                        28061        10                  6460
# 4                        24964         5                  5693
#
# ...

# %%
df.to_csv('../data/cleaned/police_force_area_mar_2022.csv')
