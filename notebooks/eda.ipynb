# %%
import geopandas as gpd

# %%
gdf = gpd.read_file('../data/Cleaned/Local_Authority_Districts_May_2024_Boundaries.gpkg')

# %%
gdf.head()
# Out:
#      LAD24CD               LAD24NM LAD24NMW   BNG_E   BNG_N     LONG  \
# 0  E06000001            Hartlepool           447161  531473 -1.27017
# 1  E06000002         Middlesbrough           451141  516887 -1.21099
# 2  E06000003  Redcar and Cleveland           464330  519596 -1.00656
# 3  E06000004      Stockton-on-Tees           444940  518179 -1.30664
# 4  E06000005            Darlington           428029  515648 -1.56835
#
#          LAT                                GlobalID  \
# 0  54.676102  {A9CBE1D9-778D-4554-85A3-3D9ED1BBD7F9}
# 1  54.544701  {A59E4D92-52B8-403E-9F99-907D6E61A275}
# 2  54.567501  {F8498D74-A639-443F-BB9E-11EB475167A1}
# 3  54.556900  {5FE93391-E03E-44B9-AC57-84A300C33154}
# 4  54.535301  {BB50D265-F4BD-4197-B17F-E0FCF7061AEA}
#
#                                             geometry
# 0  MULTIPOLYGON (((447213.900 537036.104, 447206....
# 1  MULTIPOLYGON (((448609.900 521982.600, 448586....
# 2  MULTIPOLYGON (((455741.497 528178.955, 455742....
# ...

# %%
gdf.plot()
# Out:
# <Axes: >
